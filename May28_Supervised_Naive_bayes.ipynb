# %% [markdown]
# # Naive Bayes -- Important
#
# https://scikit-learn.org/stable/modules/naive_bayes.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/Titanic-Dataset.csv.xls')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 422          423         0       3                         Zimmerman, Mr. Leo
# 745          746         0       1               Crosby, Capt. Edward Gifford
# 812          813         0       2                  Slemen, Mr. Richard James
# 439          440         0       2     Kvillner, Mr. Johan Henrik Johannesson
# 576          577         1       2                       Garside, Miss. Ethel
# 347          348         1       3  Davison, Mrs. Thomas Henry (Mary E Finck)
# 296          297         0       3                         Hanna, Mr. Mansour
# 711          712         0       1                         Klaber, Mr. Herman
# 869          870         1       3            Johnson, Master. Harold Theodor
# 648          649         0       3                         Willey, Mr. Edward
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %%
df = df[['Pclass', 'Sex', 'Age', 'Fare', 'Survived']]
df
# Out:
#      Pclass     Sex   Age     Fare  Survived
# 0         3    male  22.0   7.2500         0
# 1         1  female  38.0  71.2833         1
# 2         3  female  26.0   7.9250         1
# 3         1  female  35.0  53.1000         1
# 4         3    male  35.0   8.0500         0
# ..      ...     ...   ...      ...       ...
# 886       2    male  27.0  13.0000         0
# 887       1  female  19.0  30.0000         1
# 888       3  female   NaN  23.4500         0
# 889       1    male  26.0  30.0000         1
# 890       3    male  32.0   7.7500         0
#
# [891 rows x 5 columns]

# %%
df[df.Survived == 1]
# Out:
#      Pclass     Sex   Age     Fare  Survived
# 1         1  female  38.0  71.2833         1
# 2         3  female  26.0   7.9250         1
# 3         1  female  35.0  53.1000         1
# 8         3  female  27.0  11.1333         1
# 9         2  female  14.0  30.0708         1
# ..      ...     ...   ...      ...       ...
# 875       3  female  15.0   7.2250         1
# 879       1  female  56.0  83.1583         1
# 880       2  female  25.0  26.0000         1
# 887       1  female  19.0  30.0000         1
# 889       1    male  26.0  30.0000         1
#
# [342 rows x 5 columns]

# %% [markdown]
# # Naive Bayes Conditional Independence
#
# *   probabilistic model-> based upon conditional probab
# eg: what is the P(A) given B already happened
# formula= P(A|B) = {P(B|A)P(A)} / P(B)
# goal= is to predict "y"
#
# P(Y|X) ={P(X|Y)P(Y)} / P(X)
#
# P(Y|X) = {P(x1,x2,x3,x4....xn|Y).P(Y) / P(X)
# -> denominator will remain same, we'll consider numerator for calctn.
#
#
#
# *   List item
